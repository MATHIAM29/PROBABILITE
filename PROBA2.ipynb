# %%
"""
MATHIAM FAYE 
THILOR SENE
FATOU DIARRA
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

N=5000
n=10000
def estime(N,n):
    s=[]
    for k in range(N):
        x=np.random.chisquare(2,n)
        X=x.sum()/n
        zn=np.sqrt(n)*(X-2)/2
        s.append(zn)
    return s
hk=estime(N,n)
y=np.random.normal(0,1,n)

axes = plt.axes()
axes.grid() # dessiner une grille pour une meilleur lisibilité du graphe
plt.hist(hk) 
plt.show()
print('l\'histogramme est centré en 0 et l\'ecart entre le 0 et la premiere valeur vaut 1. Donc  à les meme caracteristiques que densité d’une loi normale centrée réduite N(0,1). Donc la variable aleatoire hk verifie les proprietés du theoreme centrale limite et converge en loi vers la loi normale centrée reduite')

from math import *
def normale(x, mu=0, sigma=1):
    sqrt_two_pi= np.sqrt(2*np.pi)
    return (np.exp(-(x-mu)**2/2/sigma**2)/(sqrt_two_pi*sigma))

xs=[x/10.0 for x in range(-40, 40)]
plt.plot(xs,[normale(x,sigma=1) for x in xs],'-',label='mu=0,sigma=1')
# Out:
# l'histogramme est centré en 0 et l'ecart entre le 0 et la premiere valeur vaut 1. Donc  à les meme caracteristiques que densité d’une loi normale centrée réduite N(0,1). Donc la variable aleatoire hk verifie les proprietés du theoreme centrale limite et converge en loi vers la loi normale centrée reduite
